# %%
import numpy as np
import pandas as pd
from astropy.io import ascii
import utils
import matplotlib.pyplot as plt
import seaborn as sns

# %%
datasets = "../datasets/SuperCOSMOS/"

# %%
uki823_df = ascii.read(datasets + "UKI823/sssedrpair.dat").to_pandas()
#ukr823_df = ascii.read(datasets + "UKR823/sssedrpair.dat").to_pandas()
#ukj823_df = ascii.read(datasets + "UKJ823/sssedrpair.dat").to_pandas()

# %%
uki823_df.columns = utils.col_names
#ukr823_df.columns = utils.col_names
#ukj823_df.columns = utils.col_names

# %%
uki823_df.sample(7)
# Out:
#               RA      DEC      XMIN      XMAX      YMIN      YMAX  AREA  \
# 2260   626651185   -22584  26269181  26273180  16242970  16248970    14
# 12817    1145555   896978  17630425  17632424  19074937  19079937     8
# 14924     513551   593777  19568922  19575920  18141938  18147938    29
# 12191     280158   358305  20279738  20297733  17410939  17452939   250
# 487    626646610 -1849852  26273180  26285177  10625972  10638972   102
# 9060     1050197 -1655217  17912353  17923351  11230939  11241939    49
# 11660    1441978   189801  16712665  16725661  16898938  16913938   127
#
#           IPEAK  COSMAG      ISKY  ...  N(0,1)  PRFMAG  C_COSMAG  C_PRFMAG  \
# 2260    2266534  -18388  17582666  ...    3083  -19461    18.604    18.857
# 12817   1895746  -17727  18871596  ...      19  -19139    18.933    19.207
# 14924   3136576  -19244  18665384  ...    5023  -19975    18.153    18.299
# 12191  54156740  -23653  18643560  ...    2711  -23915    15.136    14.037
# 487    23361682  -21829  17463436  ...    -865  -21970    16.453    16.134
# 9060    5621272  -20319  17831092  ...     275  -20719    17.486    17.492
# 11660  35680684  -22393  18795052  ...    -589  -22486    16.095    15.574
#
#           RA_SDSS  DEC_SDSS  GMAG_SDSS  RMAG_SDSS  IMAG_SDSS  CLASS_SDSS
# 2260   359.044681 -0.012818  20.342283  19.366257  18.824406           3
# 12817    0.656525  0.513667  21.076649  19.870325  19.402649           6
# 14924    0.294303  0.340155  19.346930  18.810841  18.458969           3
# 12191    0.160552  0.205211  15.752919  15.083017  14.794268           6
# 487    359.042067 -1.059949  17.487543  16.846701  16.608099           6
# 9060     0.601726 -0.948373  20.726627  19.204353  18.086632           6
# 11660    0.826322  0.108681  18.317738  16.994884  16.414444           6
#
# [7 rows x 40 columns]

# %%
uki823_df.head()
# Out:
#           RA      DEC      XMIN      XMAX      YMIN      YMAX  AREA     IPEAK  \
# 0  627905166 -1862044  22405186  22421181  10590948  10604948   161  42793408
# 1  628109952  -662364  21782348  21792346  14279944  14289944    46   5089298
# 2  628195987 -1076412  21517417  21529414  13006944  13018944    87  17260390
# 3  628311942  -518403  21162509  21172507  14721942  14731942    57   7749678
# 4  627218041 -1032678  24519637  24532633  13137958  13149958    84  14814466
#
#    COSMAG      ISKY  ...  N(0,1)  PRFMAG  C_COSMAG  C_PRFMAG     RA_SDSS  \
# 0  -22923  17532226  ...    -777  -23019    15.639    14.998  359.763288
# 1  -20025  18211806  ...    4639  -20435    17.703    17.800  359.880409
# 2  -21479  17841694  ...     -51  -21669    16.723    16.460  359.929869
# 3  -20599  18688688  ...    -259  -20958    17.357    17.232  359.996295
# 4  -21295  17692354  ...     111  -21519    16.848    16.623  359.369486
#
#    DEC_SDSS  GMAG_SDSS  RMAG_SDSS  IMAG_SDSS  CLASS_SDSS
# 0 -1.067042  19.127230  17.637123  15.888538           6
# 1 -0.379610  19.122244  18.505545  18.302338           6
# 2 -0.616716  19.118631  17.716108  17.013582           6
# 3 -0.297037  19.114597  18.120455  17.692406           6
# 4 -0.591688  19.112507  17.852146  17.173191           6
#
# [5 rows x 40 columns]

# %%
#Entries and cols
print("There are {} entries and {} columns in the UKI823 DataFrame"\
      .format(uki823_df.shape[0], uki823_df.shape[1]))
# Out:
# There are 15645 entries and 40 columns in the UKI823 DataFrame

# %%
for i in range(uki823_df.shape[1]):
    sns_plot=sns.distplot(uki823_df.iloc[:,i], kde=True)
    fig=sns_plot.get_figure()
    #fig.savefig('plot_'+list(uki823_df)[i]+'_col'+str(i)+'.png')
    plt.show()
    plt.close()
